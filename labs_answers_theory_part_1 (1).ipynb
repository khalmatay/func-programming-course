# %% [markdown]
# ## Лабораторная № 1

# %% [markdown]
# ### <span style="color:blue">1. Что такое функциональное программирование и как оно отличается от императивного стиля программирования?</span>
#
#
# #### Парадигма программирования, в которой процесс вычисления трактуется как вычисление значений функций в математическом понимании последних (в отличие от функций как подпрограмм в процедурном программировании).
#
# В программировании есть два больших подхода — императивное и функциональное.
#
# Функциональное - это про функции?
#
# <span style="color:red">Нет. Функциональное — это не про функции. Функции есть почти в любых языках программирования: и в функциональных, и в императивных. Отличие функционального программирования от императивного — в общем подходе.</span>
#
# ### Императивное программирование устроено так:
#
# #### В языке есть команды, которые этот язык может выполнять.
# Эти команды можно собрать в подпрограммы, чтобы автоматизировать некоторые однотипные вычисления. В каком порядке записаны команды внутри подпрограммы, в том же порядке они и будут выполняться.
#
# #### Есть переменные, которые могут хранить данные и изменяться во время работы программы.
# Переменная — это ячейка для данных. Мы можем создать переменную нужного нам типа, положить туда какое-то значение, а потом поменять его на другое.Как называть переменные и функции, чтобы вас уважали бывалые программисты
#
# #### Если подпрограмме на вход подать какое-то значение, то результат будет зависеть не только от исходных данных, но и от других переменных.
# Например, у нас есть функция, которая возвращает размер скидки при покупке в онлайн-магазине. Мы добавляем в корзину товар стоимостью 1000 ₽, а функция должна нам вернуть размер получившейся скидки. Но если скидка зависит от дня недели, то функция сначала проверит, какой сегодня день, потом посмотрит по таблице, какая сегодня скидка.
#
# Получается, что в разные дни функция получает на вход 1000 ₽, но возвращает разные значения — так работает императивное программирование, когда всё зависит от других переменных.
#
# #### Последовательность выполнения подпрограмм регулируется программистом.
# Он задаёт нужные условия, по которым движется программа. Вся логика полностью продумывается программистом — как он скажет, так и будет. Это значит, что разработчик может точно предсказать, в какой момент какой кусок кода выполнится — код получается предсказуемым, с понятной логикой работы.
#
# Если у нас код, который считает скидку, должен вызываться только при финальном оформлении заказа, то он выполнится именно в этот момент. Он не посчитает скидку заранее и не пропустит момент оформления.
#
# #### Суть императивного программирования в том, что программист описывает чёткие шаги, которые должны привести код к нужной цели.
#
#
# ### Функциональное программирование
#
# Смысл функционального программирования в том, что мы не задаём последовательность нужных нам команд, а описываем взаимодействие между ними и подпрограммами. Это похоже на то, как работают объекты в объектно-ориентированном программировании, только здесь это реализуется на уровне всей программы.
#
# Например, в ООП нужно задать объекты и правила их взаимодействия между собой, но также можно и написать просто код, который не привязан к объектам. Он как бы стоит в стороне и влияет на работу программы в целом — отправляет одни объекты взаимодействовать с другими, обрабатывает какие-то результаты и так далее.
#
# Функциональное программирование здесь идёт ещё дальше. В нём весь код — это правила работы с данными. Вы просто задаёте нужные правила, а код сам разбирается, как их применять.
#
# Если мы сравним принципы функционального подхода с императивным, то единственное, что совпадёт, — и там, и там есть команды, которые язык может выполнять. Всё остальное — разное.
#
#
# #### Команды можно собирать в подпрограммы, но их последовательность не имеет значения.
# Нет разницы, в каком порядке вы напишете подпрограммы — это же просто правила, а правила применяются тогда, когда нужно, а не когда про них сказали.
#
# #### Переменных нет.
# Вернее, они есть, но не в том виде, к которому мы привыкли. В функциональном языке мы можем объявить переменную только один раз, и после этого значение переменной измениться не может. Это как константы — записали и всё, теперь можно только прочитать. Сами же промежуточные результаты хранятся в функциях — обратившись к нужной, вы всегда получите искомый результат.
#
# #### Функции всегда возвращают одно и то же значение, если на вход поступают одни и те же данные.
# Если в прошлом примере мы отдавали в функцию сумму в 1000 ₽, а на выходе получали скидку в зависимости от дня недели, то в функциональном программировании если функция получит в качестве параметра 1000 ₽, то она всегда вернёт одну и ту же скидку независимо от других переменных.
#
# Можно провести аналогию с математикой и синусами: синус 90 градусов всегда равен единице, в какой бы момент мы его ни посчитали или какие бы углы у нас ещё ни были в задаче. То же самое и здесь — всё предсказуемо и зависит только от входных параметров.
#
# #### Последовательность выполнения подпрограмм определяет сам код и компилятор, а не программист.
# Каждая команда — это какое-то правило, поэтому нет разницы, когда мы запишем это правило, в начале или в конце кода. Главное, чтобы у нас это правило было, а компилятор сам разберётся, в какой момент его применять.
#
# В русском языке всё работает точно так же: есть правила правописания и грамматики. Нам неважно, в каком порядке мы их изучили, главное — чтобы мы их вовремя применяли при написании текста или в устной речи. Например, мы можем сначала пройти правило «жи-ши», а потом правило про «не с глаголами», но применять мы их будем в том порядке, какой требуется в тексте.
#
# <span style="color:green">Получается, что смысл функционального программирования в том, чтобы описать не сами чёткие шаги к цели, а правила, по которым компилятор сам должен дойти до нужного результата.</span>

# %% [markdown]
# ### <span style="color:blue">2. Каковы преимущества использования функционального подхода в программировании?</span>
#
# #### Функциональное программирование помогает сделать код более понятным, предсказуемым и легким для чтения. Использование принципов функционального программирования помогает избавиться от ненужных абстракций с непредсказуемым поведением, поэтому сделать программу более предсказуемой и уменьшить количество возможных ошибок. В функциональных языках функции могут быть переданы другим функциям в качестве аргумента или возвращены в результате.
#
# ### <span style="color:blue">3. Что такое чистая функция? Приведите пример?</span>
#
# #### Чистая функция - это функция, которая всегда возвращает один и тот же результат при одних и тех же входных данных и не имеет никаких побочных эффектов. Побочным эффектом является любое изменение, которое функция вносит в состояние системы или ее окружения за пределами своей области видимости.
#
# Примеры:

# %%
def add_numbers(x, y):
    return x + y

def multiply_numbers(x, y):
    return x * y

def is_even(x):
    return x % 2 == 0

# %% [markdown]
# ### <span style="color:blue">4. Что такое лямбда-функции в Python и как они используются?</span>
#
# #### Лямбда функции в Python – это такие функции, которые не имеют названия. Их также называют анонимными. Слово «lambda» является служебным, и не отражает сути конкретной функции. Основная причина применения лямбда функций — создание функции, которая используется в коде единожды. Использование таких функций позволяет снизить число строк кода, которые вам придется написать.
#
# ### <span style="color:blue">5. Как работают функции `map`, `filter` и `reduce`? Приведите примеры их использования.</span>
#
# #### `map()`, `filter()` и `reduce()` являются встроенными функциями Python. Эти функции обеспечивают функциональный программный аспект Python. В функциональном программировании передаваемые аргументы являются единственными факторами, которые определяют результат. Эти функции могут принимать любую другую функцию в качестве параметра и могут быть переданы другим функциям в качестве параметров.
#
# Функция `map()` является типом высшего порядка. Как упоминалось ранее, эта функция принимает другую функцию в качестве параметра вместе с итерируемой последовательностью и возвращает выходные данные после применения функции на каждый итерируемый элемент из последовательности. Синтаксис выглядит следующим образом:
#
# `map(function, iterables)`
#
# Здесь функция определяет выражение, которое в свою очередь применяется к итерируемым элементам. Функция map может принимать функции, которые определил сам пользователь, а также лямбда-функции в качестве параметра.

# %%
def newfunc(a):
    return a * a

x = map(newfunc, (1,2,3,4)) # x - это объект типа map
print(x)
print(list(x))
# Out:
# ...
# [1, 4, 9, 16]

# %% [markdown]
# Функция `filter()` используется для создания списка, состоящего из значений, для которых функция возвращает true. Синтаксис этого следующий:
#
# `filter(function, iterables)`
#
# Так же, как и `map()`, эта функция может использовать в качестве параметра пользовательские функции, а также lambda-функции.
#
# Пример:

# %%
def func(x):
    if x >= 3:
        return x
y = filter(func, (1,2,3,4))  
print(y)
print(list(y))
# Out:
# ...
# [3, 4]

# %% [markdown]
# Функция `reduce()`, как можно понять из названия, применяет переданную функцию к итерируемому объекту и возвращает одно значение.

# %% [markdown]
# `reduce(function, iterables)`
#
# Здесь функция определяет, какое выражение необходимо применить к итерируемому объекту. Эту функцию необходимо импортировать из модуля functools.
#
# Пример:

# %%
from functools import reduce
reduce(lambda a, b: a + b, [23, 21, 45, 98])
# Out:
# 187

# %% [markdown]
# В приведенном выше примере функция reduce последовательно суммирует каждый элемент из списка и возвращает одно выходное значение.
#
# Функции `map()`, `filter()` и `reduce()` в Python могут использоваться вместе друг с другом.

# %% [markdown]
# Когда вы совместно друг с другом используете функции, то сначала исполняются внутренние функции, а затем внешние функции обрабатывают результат выполнения внутренних функций.

# %%
c = map(lambda x: x + x,filter(lambda x: (x >= 3), (1, 2, 3, 4)))
print(list(c))
# Out:
# [6, 8]

# %% [markdown]
# ### <span style="color:blue">6. Как можно реализовать рекурсию в Python и какие есть ограничения?</span>
#
# #### Для того, чтобы реализовать рекурсию нужно ответить на следующие вопросы:
#
#  1. Какой случай (для какого набора параметров) будет крайним (простым) и что функция возвращает в этом случае?
#  2. Как свести задачу для какого-то набора параметров (за исключением крайнего случая) к задаче, для другого набора параметров (как правило, с меньшими значениями)?
#
# #### При этом программирование рекурсии выглядит так. Функция должна сначала проверить, не является ли переданный набор параметров простым (крайним) случаем. В этом случае функция должна вернуть значение (или выполнить действия), соответствующие простому случаю. Иначе функция должна вызвать себя рекурсивно для другого набора параметров, и на основе полученных значений вычислить значение, которое она должна вернуть.
#
# #### В Python есть ограничение на глубину рекурсии это связано с понятием стека вызовов - это область памяти, в которой выполняются функции. При каждом вызове функции создается фрейм – фрагмент памяти, – в котором содержится:
#
#  * информация о текущем состоянии выполнения функции;
#  * значения всех переменных, которые функция получила для обработки;
#  * локальные данные, созданные во время очередного вызова;
#  * сведения о строке программы, к которой нужно вернуться после выполнения функции.
#
# #### Фреймы помещаются в стек вызовов и удаляются точно так же, сверху вниз. Рекурсивные функции при каждом новом вызове используют данные, созданные во время работы предыдущего вызова.
#
# #### Программисту не нужно беспокоиться о работе стека вызовов – созданием фреймов и управлением стеком занимается интерпретатор. Однако понимание принципа работы стека вызовов значительно упрощает создание рекурсивных функций.
#
# #### Интерпретатор Python автоматически отслеживает переполнение стека и после 3000(в разных версиях языка может чуть отличаться) бесплодных вызовов завершает работу подобных функций с ошибкой:
#
# ### <span style="color:blue">7. Какие вы знаете способы оптимизации рекурсивных функций в Python?</span>
#
# #### Существуют разные способы оптимизации рекурсивных функций в Python. Вот некоторые из них:
#
#  1. Использование цикла вместо рекурсии. Циклический код не вызывает функцию заново, что уменьшает время выполнения программы.
#
#  2. Использование хвостовой рекурсии. Хвостовая рекурсия подразумевает использование рекурсии вместо цикла, при этом последней операцией является рекурсивный вызов. В Python для использования хвостовой рекурсии можно использовать декоратор @tailrecursive библиотеки python-tailrecursion.
#
#  3. Если применение рекурсии при решении задачи неизбежно, есть простой способ ускорить выполнение функции - для этого используют мемоизацию(функция кеширует результаты своего вызова). В Python для этого можно использовать декоратор @lru_cache() модуля functools.
#
#
# ### <span style="color:blue">8. Как функциональное программирование может улучшить читаемость и поддерживаемость кода?</span>
#
# #### Функции являются основными строительными блоками функционального программирования на Python. Они представляют собой отдельные блоки кода, которые могут принимать аргументы и возвращать результаты. Функции позволяют создавать код, который можно повторно использовать, упрощает его понимание и облегчает разработку.
#
# Функциональное программирование на Python основывается на нескольких ключевых концепциях:
#
# * Неизменяемость данных: в функциональном программировании данные считаются неизменяемыми. Вместо того чтобы изменять данные напрямую, в функциональном программировании используется подход, при котором создаются новые данные на основе имеющихся.
# * Функции высшего порядка: в функциональном программировании функции могут принимать другие функции в качестве аргументов и возвращать их в качестве результатов. Это позволяет создавать более абстрактные и гибкие функции.
# * Рекурсия: рекурсия является важным инструментом функционального программирования. Она позволяет вызывать функцию из самой себя, что может быть полезным для решения некоторых задач.
#
# Как и в любой другой парадигме программирования, в функциональном программировании важно понимать основные принципы и правила. Наряду с основополагающими концепциями, функциональное программирование на Python включает использование различных функций и методов для обработки данных, создания комплексных алгоритмов и решения задач.
#
# В заключение, функциональное программирование на Python предоставляет разработчикам мощный инструментарий для создания эффективных программ. Основы функционального программирования позволяют использовать функции для решения задач и создания более гибкого и поддерживаемого кода.
#
# #### В функциональном программировании функции рассматриваются как математические объекты, которые принимают одни значения и возвращают другие значения. Функции могут использоваться в качестве аргументов для других функций, создавая высокоуровневые конструкции и облегчая разработку программ.
#
# ### <span style="color:blue">9. В чем разница между изменяемыми и неизменяемыми типами данных в Python? Приведите примеры.</span>
#
# Если достаточно формально подходить к вопросу о типизации языка Python, то можно сказать, что он относится к языкам с неявной сильной динамической типизацией.
#
# Неявная типизация означает, что при объявлении переменной вам не нужно указывать её тип, при явной – это делать необходимо. В качестве примера языков с явной типизацией можно привести Java, C++.
#
# В Python типы данных можно разделить на встроенные в интерпретатор (built-in) и не встроенные, которые можно использовать при импортировании соответствующих модулей.
#
# К основным встроенным типам относятся:
#
# * None (неопределенное значение переменной)
# * Логические переменные (Boolean Type)
# * Числа (Numeric Type)
#  - int – целое число
#  - float – число с плавающей точкой
#  - complex – комплексное число
# * Списки (Sequence Type)
#  - list – список
#  - tuple – кортеж
#  - range – диапазон
# * Строки (Text Sequence Type )
#  - str
# * Бинарные списки (Binary Sequence Types)
#  - bytes – байты
#  - bytearray – массивы байт
#  - memoryview – специальные объекты для доступа к внутренним данным объекта через protocol buffer
# * Множества (Set Types)
#  - set – множество
#  - frozenset – неизменяемое множество
# * Словари (Mapping Types)
#  - dict – словарь
#
# В Python существуют изменяемые и неизменяемые типы.
#
# К неизменяемым (immutable) типам относятся: целые числа (int), числа с плавающей точкой (float), комплексные числа (complex), логические переменные (bool), кортежи (tuple), строки (str) и неизменяемые множества (frozen set).
#
# К изменяемым (mutable) типам относятся: списки (list), множества (set), словари (dict).
#
# #### При присвоении переменной какого-то значения в памяти создается объект, и переменная ссылается на этот объект, в случае с неизменяемыми типами данных при присвоении той же переменной другого значения она будет ссылаться на другую ячейку памяти, при этом в случае с изменением значения изменяемых объектов, ссылка на ячейку памяти остается прежней
#
# ### <span style="color:blue">10. Могут ли функциональные программы быть эффективными с точки зрения производительности? Объясните свой ответ.</span>
#
#
# #### Большая проблема с предсказуемой производительностью. Использование только неизменяемых значений и рекурсии может потенциально привести к проблемам с производительностью, включая использование ОЗУ и скорость, поэтому большинство функциональных языков не являются особенно хорошим выбором для мягких или жестких систем реального времени или встроенных вычислений.
#
# Однако иногдв функциональные программы могут быть эффективными с точки зрения производительности. Хотя функциональный стиль программирования обычно не является первым выбором для высокопроизводительных приложений из-за своей особенности создания множества временных объектов и неизменяемости данных, существуют способы оптимизации функционального кода для повышения производительности:
#
# #### Ленивые вычисления:
# Rогда результат вычисления откладывается до тех пор, пока он действительно не потребуется. Это позволяет избежать вычисления ненужных результатов и оптимизировать использование памяти.
#
# #### Параллелизм и конкурентность:
# Функциональное программирование стимулирует использование параллельных и конкурентных вычислений, так как чистые функции могут быть безопасно вызваны из различных потоков или процессов без опасности возникновения гонок данных.
#
# #### Неизменяемость данных:
# Хотя неизменяемость данных может создавать некоторые накладные расходы по памяти, она облегчает распараллеливание вычислений и предотвращает побочные эффекты, что делает программу более предсказуемой и легче отлаживаемой.
#
# #### Высокоуровневые абстракции:
# Функциональные языки часто предоставляют высокоуровневые абстракции для обработки данных, такие как карты (maps), фильтры (filters) и т. д., которые могут быть оптимизированы на уровне компилятора или интерпретатора для более эффективного выполнения.
#
# #### Оптимизации компилятора:
# Некоторые функциональные языки программирования, такие как OCaml или Haskell, имеют продвинутые оптимизации компилятора, которые могут существенно улучшить производительность функционального кода.
#
# Хотя функциональное программирование не всегда является лучшим выбором для всех типов задач, оно может быть очень эффективным для определенных сценариев, особенно там, где высокая параллелизуемость и чистота функций могут принести выгоду.

# %% [markdown]
# ## Лабораторная работа № 2

# %% [markdown]
# ### <span style="color:blue">1. Что такое чистая функция в контексте функционального программирования? </span>
#
# #### Чистые функции (pure functions) — функции, результат которых зависит только от значений переданных аргументов и стабильных переменных локальной области видимости, которые при одинаковых аргументах всегда возвращают один и тот же результат, и не имеют видимых побочных эффектов, то есть не изменяют состояние программы.
#
#
# ### <span style="color:blue">2. Как неизменяемость данных влияет на функциональное программирование? </span>
#
# #### Один из основных принципов ФП состоит в том, что данные являются неизменяемыми. Это означает, что однажды созданные данные не могут быть изменены, и для внесения любых изменений требуется создание новых данных. Это позволяет избежать многих ошибок и проблем, связанных с побочными эффектами и одновременным доступом к данным со стороны разных потоков выполнения.
#
# ### <span style="color:blue">3. Приведите пример функции высшего порядка в Python. </span>
#
# #### Функция высшего порядка в Python – это функция, которая имеет другую функцию в качестве аргумента или функцию, которая возвращает другую в качестве возврата на выходе. Функции высшего порядка работают с другими функциями, указанными в программе.

# %%
def repeat(func, n):
    for i in range(n):
        func()

def hello():
    print("Hello, world!")

repeat(hello, 3)
# Out:
# Hello, world!
# Hello, world!
# Hello, world!

# %% [markdown]
# ### <span style="color:blue">4. Как можно реализовать неизменяемые структуры данных в Python? </span>
#
# #### В Python можно реализовать неизменяемые структуры данных, такие как кортежи (tuples) и неизменяемые наборы (frozensets). Эти структуры данных не могут быть изменены после создания. Вот несколько способов реализации неизменяемых структур данных:
#
# #### 1. Кортежи

# %%
my_tuple = (1, 2, 3, 'a', 'b', 'c')

# %% [markdown]
# #### 2. Неизменяемые наборы (frozensets)

# %%
my_frozenset = frozenset([1, 2, 3, 4])

# %% [markdown]
# #### 3. Классы: Вы также можете создавать собственные неизменяемые структуры данных, определив класс с методами, которые не позволяют изменять его состояние после создания объекта. Например:

# %%
class ImmutableClass:
    def __init__(self, value):
        self._value = value

    @property
    def value(self):
        return self._value

# %% [markdown]
# В этом примере value является атрибутом класса, который не может быть изменен после создания объекта класса ImmutableClass.

# %% [markdown]
# #### 4. Использование библиотек: Вы также можете использовать сторонние библиотеки, такие как attrs или dataclasses, чтобы создавать неизменяемые структуры данных с меньшим количеством шаблонного кода.

# %%
import attr

@attr.s(frozen=True)
class ImmutableClass:
    value1 = attr.ib()
    value2 = attr.ib()

# %% [markdown]
# В этом примере класс ImmutableClass создается с помощью библиотеки attrs с параметром frozen=True, что делает его неизменяемым.
#
# Выбор конкретного подхода зависит от вашего конкретного случая использования.

# %% [markdown]
# ### <span style="color:blue">5. Какие проблемы решает использование чистых функций? </span>
#
# Использование чистых функций, то есть функций, которые не имеют побочных эффектов и возвращают результат только на основе своих аргументов без изменения внешних переменных или состояний, помогает решать ряд проблем в программировании:
#
# #### Предсказуемость и устойчивость кода:
# Чистые функции всегда возвращают одинаковый результат для одних и тех же входных данных, что делает поведение программы более предсказуемым и устойчивым.
#
# #### Тестирование:
# Поскольку чистые функции зависят только от своих аргументов, их легче тестировать. Нет необходимости создавать сложные сценарии тестирования для проверки побочных эффектов или внешних состояний.
#
# #### Параллелизм и конкурентность:
# Чистые функции могут безопасно использоваться в параллельных и конкурентных средах, так как они не зависят от внешних состояний, что уменьшает вероятность возникновения состязательных условий (race conditions) и других проблем конкурентного программирования.
#
# #### Модульность и переиспользование:
# Использование чистых функций способствует созданию более модульного кода, поскольку такие функции не зависят от внешних контекстов. Это также увеличивает возможность переиспользования функций в различных частях программы или даже в других проектах.
#
# #### Легкость оптимизации:
# Поскольку чистые функции не имеют побочных эффектов, их результаты могут быть кэшированы или оптимизированы компилятором или интерпретатором.
#
# #### Декомпозиция и улучшение читаемости:
# Использование чистых функций может способствовать декомпозиции задачи на более мелкие подзадачи, что улучшает читаемость и понимание кода.
#
# Однако стоит помнить, что полностью избежать использование функций с побочными эффектами иногда невозможно или нецелесообразно, особенно при взаимодействии с внешним миром (например, ввод-вывод данных). Поэтому в реальных проектах чистые функции могут использоваться в сочетании с другими подходами.
#
#
# ### <span style="color:blue">6. Могут ли чистые функции улучшить производительность программы? Если да, то как?</span>
#
# Да, чистые функции могут улучшить производительность программы в определенных случаях. Вот несколько способов, как это может произойти:
#
# #### Кэширование результатов:
# Поскольку чистые функции всегда возвращают одинаковый результат для одинаковых входных данных, их результаты могут быть кэшированы. Это означает, что при повторных вызовах с теми же аргументами функция может вернуть сохраненный результат, вместо того чтобы вычислять его заново. Это особенно полезно для тяжеловесных вычислений, которые требуют много времени или ресурсов.
#
# #### Параллелизм и конкурентность:
# Чистые функции хорошо подходят для параллельного и конкурентного программирования, так как они не изменяют внешнее состояние. Это позволяет безопасно выполнять одну и ту же функцию параллельно на разных потоках или процессах, что может привести к улучшению производительности на многоядерных процессорах.
#
# #### Повторное использование кода:
# Поскольку чистые функции не зависят от внешних контекстов, их легче повторно использовать в различных частях программы или даже в других проектах. Это может привести к снижению дублирования кода и повышению производительности за счет повторного использования уже оптимизированных функций.
#
#
# ### <span style="color:blue">7. Что такое побочные эффекты в программировании и как они связаны с чистыми функциями?</span>
#
# #### Побочные эффекты в программировании - это изменения, которые функция вносит в состояние программы, отличное от возвращаемого ей значения. Это может включать изменения в глобальных переменных, модификацию аргументов-ссылок, выполнение ввода-вывода и другие взаимодействия с внешним миром.
#
# #### Чистые функции, напротив, не имеют побочных эффектов. Они зависят только от своих аргументов и возвращают результат, не изменяя состояния программы или окружения. Вот несколько ключевых свойств чистых функций:
#
# #### Детерминированность:
# Чистые функции всегда возвращают одинаковый результат для одних и тех же входных данных, что делает их детерминированными и предсказуемыми.
#
# #### Отсутствие побочных эффектов:
# Чистые функции не изменяют состояние программы, окружения или внешних ресурсов. Это означает, что они не взаимодействуют с другими частями программы, что делает их легче понимаемыми и отлаживаемыми.
#
# #### Порядок вычислений:
# Поскольку чистые функции не имеют побочных эффектов, порядок их вызова не имеет значения, что упрощает параллельное выполнение и оптимизацию программы.
#
# ### <span style="color:blue">8. Как функция высшего порядка может влиять на удобство и гибкость программирования?</span>
#
# #### Функция высшего порядка (higher-order function) - это функция, которая принимает другие функции в качестве аргументов и/или возвращает функции в качестве результата. Использование функций высшего порядка может существенно повысить удобство и гибкость программирования по нескольким причинам:
#
# #### Абстракция операций:
# Функции высшего порядка позволяют абстрагироваться от конкретных операций и работать с более абстрактными понятиями. Например, вы можете написать функцию, которая принимает функцию фильтрации и список, и применяет этот фильтр к списку, вместо того чтобы писать отдельный код для каждой операции фильтрации.
#
# #### Уменьшение дублирования кода:
# Использование функций высшего порядка позволяет избежать дублирования кода, так как вы можете абстрагировать общие операции в отдельные функции, которые могут быть использованы в различных контекстах.
#
# #### Увеличение гибкости:
# Функции высшего порядка делают код более гибким, так как они позволяют передавать поведение как аргумент функции. Это позволяет создавать более общие и многократно используемые функции, которые могут адаптироваться к различным сценариям использования.
#
# #### Разделение ответственностей:
# Использование функций высшего порядка способствует разделению ответственностей в коде, так как каждая функция выполняет одну конкретную задачу. Это улучшает читаемость и понимание кода, а также делает его более поддающимся изменениям и сопровождению.
#
# #### Повышение абстракции:
# Функции высшего порядка способствуют созданию более высокоуровневых абстракций в программе, что упрощает ее понимание и обслуживание. Например, вы можете использовать функции высшего порядка для создания композиций функций, что позволяет создавать сложные операции из простых компонентов.
#
# В целом, функции высшего порядка являются мощным инструментом программирования, который позволяет писать более гибкий, чистый и модульный код, что повышает его качество, обслуживаемость и масштабируемость.
#
#
# ### <span style="color:blue">9. Объясните, как можно использовать кортежи в Python для обеспечения неизменяемости данных.</span>
#
# #### Кортежи в Python - это неизменяемые последовательности элементов. Они могут быть использованы для обеспечения неизменяемости данных в различных ситуациях. Вот несколько способов, как можно использовать кортежи для этой цели:
#
# #### Хранение константных данных:
# Кортежи могут быть использованы для хранения константных данных, которые не должны изменяться в течение выполнения программы.
#
# #### Использование в качестве ключей в словарях:
# Кортежи могут быть использованы в качестве ключей в словарях, потому что они являются хешируемыми и неизменяемыми. Это может быть полезно, если ключ состоит из нескольких значений, которые не должны изменяться.
#
# #### Возвращение нескольких значений из функций:
# Кортежи часто используются для возвращения нескольких значений из функций. Поскольку кортежи неизменяемы, они обеспечивают безопасность данных при возврате нескольких значений.
#
# #### Использование в качестве аргументов функций:
# Кортежи могут быть использованы для передачи неизменяемых данных в качестве аргументов функций. Это особенно полезно, когда требуется передать несколько значений, которые не должны быть изменены внутри функции.
#
# ### <span style="color:blue">10. Каким образом неизменяемость данных влияет на параллельное и асинхронное программирование?</span>
#
# #### Неизменяемость данных играет важную роль в параллельном и асинхронном программировании, поскольку обеспечивает безопасность доступа к данным и избегает состояний гонки (race conditions), что может возникнуть при одновременном доступе к изменяемым данным из нескольких потоков или процессов. Вот несколько способов, как неизменяемость данных влияет на параллельное и асинхронное программирование:
#
# #### Безопасность доступа к данным:
# Использование неизменяемых структур данных означает, что данные не могут быть изменены после создания. Это обеспечивает безопасность доступа к данным из нескольких потоков или процессов, поскольку отсутствует возможность изменения данных во время их использования.
#
# #### Повышение параллелизма:
# Использование неизменяемых данных может повысить параллелизм в программе, так как каждый поток или процесс может безопасно работать с собственной копией данных, не беспокоясь о конфликтах при изменении данных.
#
# #### Упрощение синхронизации:
# Поскольку неизменяемые данные не требуют синхронизации доступа к ним, это упрощает код и уменьшает вероятность ошибок, связанных с многопоточностью или многопроцессорностью.
#
# #### Поддержка атомарных операций:
# Некоторые языки программирования и библиотеки предоставляют атомарные операции для работы с неизменяемыми данными, что может быть полезно при обновлении данных в многопоточной или распределенной среде.
#
# Как следствие, неизменяемость данных в параллельном и асинхронном программировании способствует безопасности, предсказуемости и производительности программы, делая ее более устойчивой к ошибкам и более легко масштабируемой.

# %% [markdown]
# ## Лабораторная работа № 3

# %% [markdown]
# ### <span style="color:blue">1. Что такое рекурсия и как она работает в контексте программирования?</span>
# ### <span style="color:blue">2. Какие основные компоненты рекурсивной функции? </span>
#
# #### Рекурсия - это процесс, при котором функция вызывает саму себя в своем определении. То есть функция использует свою собственную версию для выполнения части задачи, после чего вызывает себя снова для выполнения оставшейся части.
#
# Рекурсия в программировании работает следующим образом:
#
# #### Базовый случай:
# Каждая рекурсивная функция должна иметь базовый случай, который является условием выхода из рекурсии. Когда выполнение функции достигает базового случая, рекурсивные вызовы прекращаются, и функция начинает возвращать значения обратно по стеку вызовов.
#
# #### Шаг рекурсии:
# Это часть функции, которая вызывает саму себя с измененными аргументами. Каждый следующий шаг рекурсии приближает к базовому случаю, пока не будет достигнут условия выхода из рекурсии.
#
#
#
#
# ### <span style="color:blue">3. </span>
#
# #### Преимущества использования рекурсии:
#
# #### Простота и понятность кода:
# Рекурсивные решения могут быть более простыми и понятными, особенно для задач, которые естественно разделяются на подзадачи.
#
# #### Естественное решение некоторых задач:
# Для некоторых задач рекурсивное решение является более естественным и интуитивно понятным, чем итеративное.
#
# #### Уменьшение дублирования кода:
# Рекурсивные функции могут уменьшить дублирование кода, особенно при решении задач с большим количеством вложенных повторяющихся операций.
#
# #### Мощный инструмент для работы с деревьями и графами:
# Рекурсия является мощным инструментом для работы с структурами данных, такими как деревья и графы, где операции естественно разделяются на подзадачи.
#
# #### Недостатки использования рекурсии:
#
# #### Переполнение стека вызовов (Stack Overflow):
# При использовании глубокой рекурсии или при обработке больших данных есть риск переполнения стека вызовов, что может привести к аварийному завершению программы.
#
# #### Потребление памяти:
# Каждый рекурсивный вызов добавляет кадр в стек вызовов, что может привести к значительному потреблению памяти, особенно при большой глубине рекурсии.
#
# #### Производительность:
# Рекурсивные решения могут быть менее эффективными, чем итеративные, особенно в языках программирования, которые не оптимизируют хвостовую рекурсию.
#
# #### Сложность отладки:
# Рекурсивные решения могут быть сложными для отладки, особенно если не ясно, какие значения передаются в каждый рекурсивный вызов.
#
# #### Потеря производительности из-за вызова функции:
# В некоторых случаях вызов функции может внести некоторые накладные расходы и снизить производительность по сравнению с итеративным решением.
#
# В целом, рекурсия является мощным инструментом, который следует использовать с умом, учитывая его преимущества и недостатки. Она может быть особенно полезной для решения определенных типов задач, таких как обработка деревьев и графов, но требует осторожного подхода для избежания потенциальных проблем с производительностью и памятью.
#
#
# ### <span style="color:blue">4. Приведите пример задачи, для которой рекурсия является наилучшим решением. </span>
#
# #### Одной из классических задач, для которой рекурсия является наилучшим решением, является вычисление факториала. Эта задача идеально подходит для рекурсии, так как каждый следующий шаг рекурсии уменьшает число на 1, приближаясь к базовому случаю, когда факториал равен 1. Каждый вызов функции уменьшает задачу на 1, пока не будет достигнут базовый случай, после чего рекурсивные вызовы завершаются, и функция начинает возвращать значения по стеку вызовов.
#
# ### <span style="color:blue">5. Как вы можете избежать переполнения стека вызовов в рекурсии?</span>
#
# #### Переполнение стека вызовов в рекурсии может произойти, когда количество рекурсивных вызовов становится слишком велико и превышает доступный объем памяти стека вызовов. Одним из способов избежать переполнения стека вызовов в рекурсии является использование хвостовой рекурсии (tail recursion).
#
# Хвостовая рекурсия - это особый случай рекурсии, при которой рекурсивный вызов является последней операцией в функции. В языках программирования, поддерживающих оптимизацию хвостовой рекурсии, компилятор или интерпретатор могут оптимизировать рекурсивные вызовы, чтобы они не потребляли дополнительного места в стеке вызовов.
#
# Однако Python не является языком, который поддерживает оптимизацию хвостовой рекурсии. Тем не менее, вы можете переписать рекурсивную функцию так, чтобы она стала итеративной.
#
# Другой вариант - мемоизацию(функция кеширует результаты своего вызова)
#
#
# ### <span style="color:blue">6. Что такое хвостовая рекурсия и почему она важна? </span>
#
# См. вопрос 5
#
#
# ### <span style="color:blue">7. Как реализовать мемоизацию в рекурсивной функции? </span>
#
# #### Мемоизация - это оптимизационная техника, которая заключается в сохранении результатов выполнения функции для заданных входных данных и последующем использовании сохраненных результатов при повторных вызовах функции с теми же входными данными, вместо повторного выполнения вычислений.
#
# В рекурсивных функциях мемоизация может быть особенно полезна, чтобы избежать повторных вычислений и улучшить производительность. Вот как можно реализовать мемоизацию в рекурсивной функции на Python:

# %%
# Словарь для хранения результатов мемоизации
memo = {}

def factorial(n):
    # Проверяем, есть ли результат для данного аргумента в словаре memo
    if n in memo:
        return memo[n]
    # Базовый случай: факториал 0 равен 1
    if n == 0:
        return 1
    else:
        # Вызываем функцию рекурсивно и сохраняем результат в словаре memo
        memo[n] = n * factorial(n - 1)
        return memo[n]

# Пример вызова функции для вычисления факториала числа 5
result = factorial(5)
print(result)  # Вывод: 120
# Out:
# 120

# %% [markdown]
# В этой реализации мы используем словарь memo для хранения результатов мемоизации. Перед тем как вычислять факториал для данного числа n, мы проверяем, есть ли уже результат в словаре memo. Если результат уже вычислен, мы просто возвращаем его из словаря. Если нет, мы вычисляем факториал n с помощью рекурсии, сохраняем результат в словаре memo и затем возвращаем его.
#
# Таким образом, при повторных вызовах функции для тех же входных данных результат будет возвращен непосредственно из словаря memo, что сократит количество вычислений и улучшит производительность.

# %% [markdown]
# ### <span style="color:blue">8. Можете ли вы сравнить рекурсивный и итеративный подходы к решению
# задач? </span>
#
# См. вопрос 1 лабы № 1
#
#
# ### <span style="color:blue">9.  Какие ошибки могут возникать при написании рекурсивных функций и как их
# избежать? </span>
#
# #### Бесконечная рекурсия:
# Это случается, когда рекурсивная функция не достигает базового случая или условия завершения, что приводит к бесконечным рекурсивным вызовам. Чтобы избежать этого, убедитесь, что у вас есть базовый случай, который гарантирует завершение рекурсии, и что каждый шаг рекурсии приближает к этому базовому случаю.
#
# #### Неправильное использование глобальных переменных:
# Использование глобальных переменных в рекурсивных функциях может привести к непредсказуемому поведению и ошибкам. Рекомендуется передавать все необходимые данные в качестве аргументов функции или использовать замыкания, если это возможно, вместо зависимости от глобальных переменных.
#
# #### Неэффективное использование ресурсов:
# Некоторые рекурсивные алгоритмы могут быть неэффективными из-за повторных вычислений или из-за большого количества рекурсивных вызовов. Оцените время и пространство, необходимые для выполнения вашей рекурсивной функции, и попробуйте найти способы оптимизации, такие как мемоизация, использование хвостовой рекурсии или переход к итеративному подходу, если это возможно.
#
# #### Неправильные аргументы или условия:
# Убедитесь, что ваши рекурсивные вызовы используют правильные аргументы и учитывают все необходимые условия и ограничения. Неправильные аргументы или условия могут привести к неправильным результатам или бесконечной рекурсии.
#
# #### Стековое переполнение:
# При глубокой рекурсии или обработке больших данных может возникнуть переполнение стека вызовов. Используйте хвостовую рекурсию (если это поддерживается языком) или итеративный подход для уменьшения риска переполнения стека.
#
# #### Неявный оверхед рекурсии:
# В некоторых языках программирования каждый рекурсивный вызов создает новый кадр стека, что может привести к неявному оверхеду. В таких случаях рекурсивные решения могут быть менее эффективными, чем итеративные.
#
#
# ### <span style="color:blue">10. Как рекурсия может быть использована для обхода структур данных, таких
# как деревья и графы? </span>
#
# Рекурсия является мощным инструментом для обхода структур данных, таких как деревья и графы. Вот как рекурсия может быть использована для обхода этих структур данных:
#
# #### Обход деревьев:
# #### Прямой обход (pre-order traversal):
# В прямом обходе сначала посещается корневой узел, затем рекурсивно обходятся левое и правое поддеревья. Это полезно, например, для вывода выражения в виде префиксной записи.
#
# #### Центрированный обход (in-order traversal):
# В центрированном обходе сначала рекурсивно обходятся левое поддерево, затем посещается корневой узел, и, наконец, рекурсивно обходится правое поддерево. Это полезно, например, для обхода упорядоченных структур данных для получения элементов в порядке возрастания.
#
# #### Обратный обход (post-order traversal):
# В обратном обходе сначала рекурсивно обходятся левое и правое поддеревья, затем посещается корневой узел. Это полезно, например, для удаления всех узлов в дереве.
#
# #### Обход графов:
# #### Обход в глубину (Depth-First Search, DFS):
# Обход в глубину использует рекурсию для исследования всех узлов графа, начиная с заданного узла, и посещения всех его соседей. Это полезно, например, для поиска в глубину и определения связности графа.
#
# #### Обход в ширину (Breadth-First Search, BFS):
# Обход в ширину также может быть реализован с помощью рекурсии, хотя обычно он реализуется с использованием очереди. Однако, рекурсивный BFS может быть полезен для некоторых специфических случаев или в учебных целях.
#
# Рекурсивный подход к обходу структур данных обычно более прост и интуитивен, чем итеративный подход, особенно в случае деревьев. Однако при использовании рекурсии необходимо учитывать потенциальные ограничения по глубине рекурсии и возможность переполнения стека вызовов.
